# %% [markdown]
# 1 - Crie um dataframe usado so dados da tabela abaixo.<br>
# ![tabela.JPG](attachment:tabela.JPG)

# %% [markdown]
# 2 - Imprima a descrição desse dataframe.

# %% [markdown]
# 3 - Imprima as medias de Prova1	Prova2	Seminário.

# %% [markdown]
# 4 - Imprima a tabela ordenada pelas faltas.

# %% [markdown]
# 5 - Imprima todos os alunos que tem nota no seminario maior que 8 e nota na prova1 maior que 3.

# %% [markdown]
# 6 - Usandoo as funcoes head e tail imprima as 2 primeiras e 2 ultimas linhas.

# %% [markdown]
# 7 - Crie o campo calculado de media usando os valores de Prova1 Prova2 e Seminário.

# %% [markdown]
# 8 - Imprima apenas as linhas dos alunos que foram aprovados (média maioor que 6.0 e menos de 3 faltas).
